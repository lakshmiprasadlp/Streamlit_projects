# %%
# %%capture
# !pip install yfinance

# %%
import yfinance as yf

# %%
tickerSymbol = 'GOOGL'

# %%
tickerData = yf.Ticker(tickerSymbol)

# %%
tickerData
# Out:
# yfinance.Ticker object <GOOGL>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tickerDf = tickerData.history(period='1d', start='2010-5-31', end='2020-5-31')

# %%
tickerDf.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2010-06-01 00:00:00-04:00  11.965566  12.230316  11.957845  12.013883
# 2010-06-02 00:00:00-04:00  12.121229  12.300302  11.991220  12.287849
# 2010-06-03 00:00:00-04:00  12.331184  12.652223  12.320973  12.592448
# 2010-06-04 00:00:00-04:00  12.446003  12.683357  12.370787  12.421097
# 2010-06-07 00:00:00-04:00  12.429564  12.475640  12.033311  12.092338
#
#                               Volume  Dividends  Stock Splits
# Date
# 2010-06-01 00:00:00-04:00  106565328        0.0           0.0
# 2010-06-02 00:00:00-04:00  101530368        0.0           0.0
# 2010-06-03 00:00:00-04:00  145881972        0.0           0.0
# 2010-06-04 00:00:00-04:00  156655188        0.0           0.0
# 2010-06-07 00:00:00-04:00  145162692        0.0           0.0

# %%
tickerDf.Close.head()
# Out:
# Date
# 2010-06-01 00:00:00-04:00    12.013883
# 2010-06-02 00:00:00-04:00    12.287849
# 2010-06-03 00:00:00-04:00    12.592448
# 2010-06-04 00:00:00-04:00    12.421097
# 2010-06-07 00:00:00-04:00    12.092338
# Name: Close, dtype: float64

# %%
# prompt: drow a line chart

import matplotlib.pyplot as plt
plt.plot(tickerDf.Close)

# %%
# prompt: drow a line chart

import matplotlib.pyplot as plt
plt.plot(tickerDf.Volume)
